# %%
import numpy as np
import sklearn.datasets
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

# %% [markdown]
# # Zadanie 1
# Za pomoca funkcji
# ```python
# sklearn.datasets.make_moons
# ```
# wygeneruj 4 zbiory danych z parametrami:
#
# * n_samples=1000, noise=.05
# * n_samples=1000, noise=.3
# * n_samples=200, noise=.05
# * n_samples=200, noise=.3

# %%
#low noise, plenty of samples, should be easy
X, y = sklearn.datasets.make_moons(n_samples=1000, noise=.05)
X2, y2 = sklearn.datasets.make_moons(n_samples=1000, noise=.3)
X3, y3 = sklearn.datasets.make_moons(n_samples=200, noise=.05)
X4, y4 = sklearn.datasets.make_moons(n_samples=200, noise=.3)

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:,0],X[:,1],c=y)
plt.show()
plt.scatter(X2[:,0],X2[:,1],c=y2)
plt.show()
plt.scatter(X3[:,0],X3[:,1],c=y3)
plt.show()
plt.scatter(X4[:,0],X4[:,1],c=y4)

plt.axis('equal')
plt.show()

# %%
iris = load_iris()
X = iris.data[:, (2, 3)]  # petal length, petal width
y = (iris.target == 0).astype(np.int)

per_clf = Perceptron(max_iter=1000, tol=1e-3, random_state=42)
per_clf.fit(X, y)

per_clf2 = Perceptron(max_iter=1000, tol=1e-3, random_state=42)
per_clf.fit(X2, y2)

per_clf3 = Perceptron(max_iter=1000, tol=1e-3, random_state=42)
per_clf.fit(X3, y3)

per_clf4 = Perceptron(max_iter=1000, tol=1e-3, random_state=42)
per_clf.fit(X4, y4)

y_pred = per_clf.predict([[2, 0.5]])
# Out:
# C:\Users\mlade\AppData\Local\Temp\ipykernel_14344\3297080009.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = (iris.target == 0).astype(np.int)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\mlade\anaconda3\lib\site-packages (0.22.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\mlade\anaconda3\lib\site-packages (from mlxtend) (3.7.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\mlade\anaconda3\lib\site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\mlade\anaconda3\lib\site-packages (from mlxtend) (1.10.0)
# Requirement already satisfied: setuptools in c:\users\mlade\anaconda3\lib\site-packages (from mlxtend) (65.6.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\mlade\anaconda3\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\mlade\anaconda3\lib\site-packages (from mlxtend) (1.2.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\mlade\anaconda3\lib\site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mlade\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mlade\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mlade\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mlade\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mlade\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mlade\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mlade\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mlade\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mlade\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mlade\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\mlade\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import Perceptron
per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

per_clf2 = Perceptron(random_state=42)
per_clf2.fit(X2, y2)

per_clf3 = Perceptron(random_state=42)
per_clf3.fit(X3, y3)

per_clf4 = Perceptron(random_state=42)
per_clf4.fit(X4, y4)
# Out:
# Perceptron(random_state=42)

# %%
plot_decision_regions(X, y, clf=per_clf)
plt.show()
plot_decision_regions(X2, y2, clf=per_clf2)
plt.show()
plot_decision_regions(X3, y3, clf=per_clf3)
plt.show()
plot_decision_regions(X4, y4, clf=per_clf4)
plt.show()

# %% [markdown]
# # Zad.
# Naucz perceptron na danych iris i wylicz F1 score.

# %%
iris = load_iris()
X = iris.data[:, (2, 3)] 
y = (iris.target == 0).astype(np.int)
# Out:
# C:\Users\mlade\AppData\Local\Temp\ipykernel_14344\2651221417.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = (iris.target == 0).astype(np.int)

# %%
iris = load_iris()
X = iris.data[:, (2, 3)] 
y = (iris.target == 0).astype(np.int) 

per_clf = Perceptron(max_iter=1000, tol=1e-3, random_state=42)
per_clf.fit(X, y)

sklearn.metrics.f1_score(y, per_clf.predict(X))
# Out:
# C:\Users\mlade\AppData\Local\Temp\ipykernel_14344\2324682432.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = (iris.target == 0).astype(np.int)
# 1.0
