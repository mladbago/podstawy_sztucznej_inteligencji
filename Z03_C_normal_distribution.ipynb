# %% [markdown]
# <a href="https://colab.research.google.com/github/mladbago/podstawy_sztucznej_inteligencji/blob/main/Z03_C_normal_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wielowymiarowy rozkład normalny

# %%
import matplotlib.pylab as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.mlab as mlab
from matplotlib import cm
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zad.
# Narysujmy gęstość dwuwymiarowego rozkładu Normalnego o parametach
#
# * n=[0,0], cov = [[1,0],[0,1]]
# * n=[0,0], cov = [[2,0],[0,1]]
# * n=[0,0], cov = [[1,0],[0,2]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

n = [0, 0]
cov = [[1,0],[0,1]]

x = np.linspace(-5,5,300)
y = np.linspace(-5,5,300)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal(n, cov)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

n = [0, 0]
cov = [[2,0],[0,1]]

x = np.linspace(-5,5,300)
y = np.linspace(-5,5,300)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal(n, cov)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

n = [0, 0]
cov = [[1,0],[0,2]]

x = np.linspace(-5,5,300)
y = np.linspace(-5,5,300)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal(n, cov)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %% [markdown]
# # Zad
# Narysujmy kontury gęstości dwuwymiarowego rozkładu Normalnego o parametach
#
# * n=[0,0], cov = [[1,0],[0,1]]
# * n=[0,0], cov = [[2,0],[0,1]]
# * n=[0,0], cov = [[1,0],[0,2]]

# %%
n = [0, 0]
cov = [[1,0],[0,1]]

x = np.linspace(-3,3,300)
y = np.linspace(-3,3,300)
X, Y = np.meshgrid(x,y)
rv = multivariate_normal(n, cov)

plt.contour(X, Y, rv.pdf(pos))
plt.show()

# %%
n = [0, 0]
cov = [[2,0],[0,1]]

x = np.linspace(-3,3,300)
y = np.linspace(-3,3,300)
X, Y = np.meshgrid(x,y)
rv = multivariate_normal(n, cov)

plt.contour(X, Y, rv.pdf(pos))
plt.show()

# %%
n = [0, 0]
cov = [[1,0],[0,2]]

x = np.linspace(-3,3,300)
y = np.linspace(-3,3,300)
X, Y = np.meshgrid(x,y)
rv = multivariate_normal(n, cov)

plt.contour(X, Y, rv.pdf(pos))
plt.show()

# %% [markdown]
# # Zad
# Wylosujmy próbkę z dwuwymiarowego rozkładu Normalnego o parametach
#
# * n=[0,0], cov = [[1,0],[0,1]]
# * n=[0,0], cov = [[2,0],[0,1]]
# * n=[0,0], cov = [[1,0],[0,2]]
#
# i narysuj odpowiedni wykres

# %%
to_plot = np.random.multivariate_normal([0,0], [[1,0],[0,1]], 500)

plt.scatter(to_plot[:, 0], to_plot[:, 1])
plt.show()

# %%
to_plot = np.random.multivariate_normal([0,0], [[2,0],[0,1]], 500)

plt.scatter(to_plot[:, 0], to_plot[:, 1])
plt.show()

# %%
to_plot = np.random.multivariate_normal([0,0], [[1,0],[0,2]], 500)

plt.scatter(to_plot[:, 0], to_plot[:, 1])
plt.show()
