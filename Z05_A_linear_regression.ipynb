# %% [markdown]
# <a href="https://colab.research.google.com/github/mladbago/podstawy_sztucznej_inteligencji/blob/main/Z05_A_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

f_lr_2 = lambda x: p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

f_lr_2 = lambda x: p2[0][4]*pow(x,4) +p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4,x**5) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

f_lr_2 = lambda x: p2[0][5]*pow(x,5)+p2[0][4]*pow(x,4) +p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x, y, 'ok', ms=10);
plt.plot(x_f_lr, y_f_lr, 'c');


#####x^2
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 
y_f_lr = f_lr_2(x_tr)
plt.plot(x_f_lr, y_f_lr, 'b');


####x^3
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_2 = lambda x: p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 
y_f_lr = f_lr_2(x_tr)
plt.plot(x_f_lr, y_f_lr, 'r');

#####x^4
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_2 = lambda x: p2[0][4]*pow(x,4) +p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 
y_f_lr = f_lr_2(x_tr)
plt.plot(x_f_lr, y_f_lr, 'b');


####x^5
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4,x**5) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_2 = lambda x: p2[0][5]*pow(x,5)+p2[0][4]*pow(x,4) +p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 
y_f_lr = f_lr_2(x_tr)
plt.plot(x_f_lr, y_f_lr, 'g');
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.462
# Dependent Variable: y                AIC:                609.0111
# Date:               2023-04-19 15:55 BIC:                614.2214
# No. Observations:   100              Log-Likelihood:     -302.51
# Df Model:           1                F-statistic:        86.07
# Df Residuals:       98               Prob (F-statistic): 4.48e-15
# R-squared:          0.468            Scale:              25.341
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -2.8069     1.0704   -2.6223   0.0101   -4.9310   -0.6827
# x1         5.7087     0.6153    9.2773   0.0000    4.4876    6.9299
# -----------------------------------------------------------------
# Omnibus:             42.965       Durbin-Watson:          2.369
# Prob(Omnibus):       0.000        Jarque-Bera (JB):       109.339
# Skew:                1.583        Prob(JB):               0.000
# Kurtosis:            7.027        Condition No.:          5
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -22.9292
# Date:               2023-04-19 15:55 BIC:                -7.2982
# No. Observations:   100              Log-Likelihood:     17.465
# Df Model:           5                F-statistic:        2.122e+04
# Df Residuals:       94               Prob (F-statistic): 8.15e-142
# R-squared:          0.999            Scale:              0.043924
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025     0.975]
# --------------------------------------------------------------------
# const     -0.5408     0.1628   -3.3216   0.0013    -0.8641   -0.2175
# x1         7.5213     1.0359    7.2606   0.0000     5.4645    9.5782
# x2         2.3371     2.0410    1.1451   0.2551    -1.7153    6.3895
# x3        -8.3797     1.6804   -4.9868   0.0000   -11.7161   -5.0433
# x4         3.1970     0.6087    5.2517   0.0000     1.9883    4.4056
# x5        -0.1566     0.0802   -1.9528   0.0538    -0.3159    0.0026
# ------------------------------------------------------------------
# Omnibus:               4.157        Durbin-Watson:           1.884
# Prob(Omnibus):         0.125        Jarque-Bera (JB):        4.166
# Skew:                  0.487        Prob(JB):                0.125
# Kurtosis:              2.775        Condition No.:           9721
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     86.07
# Date:                Wed, 19 Apr 2023   Prob (F-statistic):           4.48e-15
# Time:                        15:55:40   Log-Likelihood:                -302.51
# No. Observations:                 100   AIC:                             609.0
# Df Residuals:                      98   BIC:                             614.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.8069      1.070     -2.622      0.010      -4.931      -0.683
# x              5.7087      0.615      9.277      0.000       4.488       6.930
# ==============================================================================
# Omnibus:                       42.965   Durbin-Watson:                   2.369
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              109.339
# Skew:                           1.583   Prob(JB):                     1.81e-24
# Kurtosis:                       7.027   Cond. No.                         4.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     167.1
# Date:                Wed, 19 Apr 2023   Prob (F-statistic):           3.80e-32
# Time:                        15:55:40   Log-Likelihood:                -259.44
# No. Observations:                 100   AIC:                             524.9
# Df Residuals:                      97   BIC:                             532.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.3027      1.056      5.968      0.000       4.207       8.399
# x            -12.1197      1.600     -7.575      0.000     -15.295      -8.944
# I(x ** 2)      6.0344      0.524     11.513      0.000       4.994       7.075
# ==============================================================================
# Omnibus:                       11.830   Durbin-Watson:                   2.181
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.585
# Skew:                           0.733   Prob(JB):                      0.00185
# Kurtosis:                       3.934   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
